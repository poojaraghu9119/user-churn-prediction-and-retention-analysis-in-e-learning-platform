# %% [markdown]
# ### PROJECT
# ### Students' dropout and academic success prediction

# %% [markdown]
# #### Problem Statement
# ##### This project aims to predict student academic outcomes and analyze the underlying factors behind student dropout, so that institutions can take early, data-driven actions to improve student retention.

# %% [markdown]
# #### Data collection
# ##### Data Source - https://archive.ics.uci.edu/dataset/697/predict+students+dropout+and+academic+success

# %% [markdown]
# #### Import Data and Required Packages
# ##### Importing Pandas, Numpy, Matplotlib, Seaborn and Warings Library.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
